# %% [markdown]
# # Basic setup

# %%
# loading python packages
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd
import os
import matplotlib.pylab as plt
import numpy as np
import seaborn as sns
from natsort import natsorted, ns
import glob
from pymer4.models import Lmer
# %load_ext rpy2.ipython

fpath = 'where/you/have/the/data'

# %%
# %%R
# # loading R packages
# library('lme4')
# library('lmerTest')
# library('lsmeans')

# %% [markdown]
# # Doctor - Conditioning - Overall pain rating

# %%
doc_data = pd.read_csv(os.path.join(fpath,'study3_doc_condition_rating_data.csv'))
doc_mean = doc_data.groupby(['DyadID','Condition'])['Pain_Rating'].mean().reset_index()

# %% [markdown]
# ## Figure 4(A-3)

# %%
sns.set(style="ticks", font_scale=1.3)
g = sns.catplot(x="Condition", y="Pain_Rating", palette={'Thermedol':'dodgerblue','Vaseline':'red'},units='DyadID',
                   n_boot=5000, ci=68, data=doc_mean, kind="bar", order=['Vaseline','Thermedol'], aspect=.8)
g = sns.stripplot(x="Condition", y="Pain_Rating", palette={'Thermedol':'lightskyblue','Vaseline':'lightsalmon'},
                   data=doc_mean, order=['Vaseline','Thermedol'],alpha=.5)

g.set(ylim=(0, 100))
plt.ylabel('Pain rating')
plt.xlabel('')
g.set_xticklabels(["Control","Thermedol"])
# Out:
# [Text(0, 0, 'Control'), Text(1, 0, 'Thermedol')]

# %%
doc_data['trials_c'] = doc_data.Trials - doc_data.Trials.mean()

# %%
# %%R -i doc_data
# doc_data$Site <- factor(doc_data$Site)
# doc_data$Color <- factor(doc_data$Current_color)
# doc_data$Condition <- factor(doc_data$Condition_new)
#
# doc_overall_m <- lmer(Pain_Rating ~ Site + trials_c + Color + Condition +
#                          (1 + trials_c + Condition| DyadID), data = doc_data)
#
# summary(doc_overall_m)
# Out:
# Linear mixed model fit by REML t-tests use Satterthwaite approximations to
#   degrees of freedom [lmerMod]
# Formula: Pain_Rating ~ Site + trials_c + Color + Condition + (1 + trials_c +
#     Condition | DyadID)
#    Data: doc_data
#
# REML criterion at convergence: 1906.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.1947 -0.5321 -0.0617  0.5814  2.5595
#
# Random effects:
#  Groups   Name        Variance Std.Dev. Corr
#  DyadID   (Intercept) 273.258  16.531
#           trials_c      1.767   1.329    0.26
#           Condition1  176.013  13.267   -0.99 -0.40
#  Residual             136.291  11.674
# Number of obs: 240, groups:  DyadID, 30
#
# Fixed effects:
#              Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)  39.44988    3.68397  47.41000  10.709 3.02e-14 ***
# Site2        -1.55994    2.14611 187.19000  -0.727    0.468
# Site3        -0.88889    2.43053 116.89000  -0.366    0.715
# Site4        -0.09865    2.43041 118.17000  -0.041    0.968
# trials_c      4.06909    0.71767  49.67000   5.670 7.23e-07 ***
# Color1        1.69168    1.90314  59.00000   0.889    0.378
# Condition1  -31.92188    2.89484  30.02000 -11.027 4.43e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#            (Intr) Site2  Site3  Site4  trls_c Color1
# Site2      -0.292
# Site3      -0.331  0.438
# Site4      -0.330  0.440  0.612
# trials_c    0.054  0.060  0.026  0.026
# Color1     -0.345  0.003  0.134  0.130  0.000
# Condition1 -0.796  0.001 -0.085 -0.086 -0.113  0.110

# %% [markdown]
# # Doctor - Conditioning - Belief of Effectiveness

# %%
doc_q = pd.read_csv(os.path.join(fpath,'study3_doc_condition_belief_data.csv'))

# %%
doc_q_pre = doc_q[doc_q['Time']==0].reset_index(drop=True)
doc_q_post = doc_q[doc_q['Time']==1]

effect_diff = doc_q_post['Effectiveness'].values - doc_q_pre['Effectiveness'].values
effect_diff = pd.DataFrame(effect_diff, columns = ['Effective_change'])

effect_diff['DyadID'] = doc_q_pre['DyadID']

effect_diff['Condition'] = 'Thermedol'

# %% [markdown]
# ## Figure. 4(A-2, left panel)

# %%
sns.set(style="ticks", font_scale=1.3)
g = sns.factorplot(x="Condition", y="Effective_change", palette={'Thermedol':'dodgerblue'},units='DyadID',
                   n_boot=5000, ci=68, data=effect_diff, kind="bar", aspect=.5)

g = sns.stripplot(x="Condition", y="Effective_change", 
    palette={'Thermedol':'lightskyblue'},
    data=effect_diff,alpha=.5)

g.set(ylim=(0, 100))
plt.ylabel('Average Increase in Belief')
plt.xlabel('')

g.set_xticklabels(["Thermedol"])
# Out:
# /Users/PinhaoChen/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# [Text(0, 0, 'Thermedol')]

# %%
# %%R -i doc_q
# doc_q$Time <- factor(doc_q$Time)
# effectivness_model <- lmer(Effectiveness ~ Time + (1 | DyadID), data = doc_q)
# summary(effectivness_model)
# Out:
# Linear mixed model fit by REML t-tests use Satterthwaite approximations to
#   degrees of freedom [lmerMod]
# Formula: Effectiveness ~ Time + (1 | DyadID)
#    Data: doc_q
#
# REML criterion at convergence: 507.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.0563 -0.3844  0.1453  0.4799  1.9316
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  DyadID   (Intercept) 110.0    10.49
#  Residual             234.2    15.30
# Number of obs: 60, groups:  DyadID, 30
#
# Fixed effects:
#             Estimate Std. Error     df t value Pr(>|t|)
# (Intercept)   51.451      3.387 52.630  15.191  < 2e-16 ***
# Time1         25.887      3.951 29.000   6.552 3.55e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#       (Intr)
# Time1 -0.583

# %% [markdown]
# ## Figure. 4(A-2, right panel) - doctors' beliefs during interaction phase

# %%
doc_q_interact = pd.read_csv(os.path.join(fpath,'study3_doc_interaction_belief_data.csv'))

# %%
doc_q_interact_pre = doc_q_interact[doc_q_interact['Time_new']=='pre'].reset_index(drop=True)
doc_q_interact_pre_first2 = doc_q_interact_pre.iloc[0:60]

# %%
sns.set(style="ticks", font_scale=1.3)
g = sns.catplot(x="Condition_new", y="effectiveness", 
                palette={'Thermedol':'dodgerblue','Vaseline':'red'},units='DyadID',
                   n_boot=5000, ci=68, data=doc_q_interact_pre_first2, kind="bar", 
                order=['Vaseline','Thermedol'], aspect=.8)

g = sns.stripplot(x="Condition_new", y="effectiveness", 
                  palette={'Thermedol':'lightskyblue','Vaseline':'lightsalmon'},
                   data=doc_q_interact_pre_first2, order=['Vaseline','Thermedol'],alpha=.5)

g.set(ylim=(0, 101))
plt.ylabel('Belief of Effectiveness')
plt.xlabel('')
g.set_xticklabels(["Control","Thermedol"])
# Out:
# [Text(0, 0, 'Control'), Text(1, 0, 'Thermedol')]

# %%
# %%R -i doc_q_interact
# doc_q_interact$Time <- factor(doc_q_interact$Time)
# doc_q_interact$Condition <- factor(doc_q_interact$Condition)
# doc_effectivness_model <- lmer(effectiveness ~ Time*Condition+ (1 + Time + Condition | DyadID)
#                                , data = doc_q_interact)
# summary(doc_effectivness_model)
# Out:
# Linear mixed model fit by REML t-tests use Satterthwaite approximations to
#   degrees of freedom [lmerMod]
# Formula: effectiveness ~ Time * Condition + (1 + Time + Condition | DyadID)
#    Data: doc_q_interact
#
# REML criterion at convergence: 1831.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.9529 -0.5234 -0.1128  0.4815  3.7072
#
# Random effects:
#  Groups   Name        Variance Std.Dev. Corr
#  DyadID   (Intercept)  99.695   9.985
#           Time2         2.152   1.467    0.14
#           Condition1  260.058  16.126   -0.77  0.53
#  Residual              80.438   8.969
# Number of obs: 240, groups:  DyadID, 30
#
# Fixed effects:
#                  Estimate Std. Error      df t value Pr(>|t|)
# (Intercept)        17.222      2.160  34.120   7.975 2.65e-09 ***
# Time2               1.124      1.659 159.560   0.677    0.499
# Condition1         62.571      3.369  37.180  18.573  < 2e-16 ***
# Time2:Condition1   -3.450      2.316 178.000  -1.490    0.138
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) Time2  Cndtn1
# Time2       -0.355
# Condition1  -0.750  0.314
# Tim2:Cndtn1  0.268 -0.698 -0.344
